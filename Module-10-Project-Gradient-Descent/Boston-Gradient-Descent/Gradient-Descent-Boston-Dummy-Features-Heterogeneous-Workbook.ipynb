# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import pandas as pd
from sklearn import preprocessing

# %%
data = np.loadtxt("Boston-Training-Data.csv",delimiter=",")

# %%
data.shape
# Out:
# (379, 14)

# %%
X = data[:,0:13]
Y = data[:,13]

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_scaled = scaler.transform(X)

# %%
X_scaled.shape,Y.shape
# Out:
# ((379, 13), (379,))

# %%
df = pd.DataFrame(X_scaled)
df.describe()
# Out:
#                  0             1             2             3             4   \
# count  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02
# mean   1.508614e-17  8.290056e-17  6.122338e-17 -2.132566e-16  6.151632e-17
# std    1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00
# min   -4.102327e-01 -4.904269e-01 -1.528467e+00 -2.878492e-01 -1.497147e+00
# 25%   -4.012816e-01 -4.904269e-01 -8.894918e-01 -2.878492e-01 -9.087619e-01
# 50%   -3.783546e-01 -4.904269e-01 -2.131836e-01 -2.878492e-01 -1.732805e-01
# 75%    3.337478e-02  1.536939e-01  9.642533e-01 -2.878492e-01  6.011382e-01
# max    9.307084e+00  3.803712e+00  2.348460e+00  3.474042e+00  2.708076e+00
#
#                  5             6             7             8             9   \
# count  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02
# mean   2.167718e-17  7.323371e-17  3.280870e-17 -6.444566e-17  3.866740e-17
# std    1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00
# min   -3.913028e+00 -2.412655e+00 -1.233168e+00 -1.011062e+00 -1.332947e+00
# 25%   -6.037702e-01 -8.205934e-01 -8.072353e-01 -6.712517e-01 -7.848638e-01
# 50%   -1.357009e-01  3.052342e-01 -3.194761e-01 -5.579817e-01 -4.758382e-01
# 75%    4.969408e-01  8.871226e-01  6.580571e-01  1.594148e+00  1.459945e+00
# max    3.523362e+00  1.096747e+00  3.859730e+00  1.594148e+00  1.722325e+00
#
#                  10            11            12
# count  3.790000e+02  3.790000e+02  3.790000e+02
# mean   2.929348e-18 -3.368751e-18  1.288913e-17
# std    1.001322e+00  1.001322e+00  1.001322e+00
# min   -2.729394e+00 -3.812178e+00 -1.528096e+00
# 25%   -5.077771e-01  2.103323e-01 -8.355463e-01
# 50%    2.790454e-01  3.850455e-01 -1.775552e-01
# 75%    7.881658e-01  4.393022e-01  6.200517e-01
# max    1.621272e+00  4.503265e-01  3.344633e+00

# %%
features = df.columns

for feature1 in range(len(features)):
    for feature2 in range(feature1,len(features)):
        comp_feature = str(feature1) + "_" + str(feature2)
        df[comp_feature] = df[feature1]*df[feature2]
df.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02
# mean   1.508614e-17  8.290056e-17  6.122338e-17 -2.132566e-16  6.151632e-17
# std    1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00
# min   -4.102327e-01 -4.904269e-01 -1.528467e+00 -2.878492e-01 -1.497147e+00
# 25%   -4.012816e-01 -4.904269e-01 -8.894918e-01 -2.878492e-01 -9.087619e-01
# 50%   -3.783546e-01 -4.904269e-01 -2.131836e-01 -2.878492e-01 -1.732805e-01
# 75%    3.337478e-02  1.536939e-01  9.642533e-01 -2.878492e-01  6.011382e-01
# max    9.307084e+00  3.803712e+00  2.348460e+00  3.474042e+00  2.708076e+00
#
#                   5             6             7             8             9  \
# count  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02  3.790000e+02
# mean   2.167718e-17  7.323371e-17  3.280870e-17 -6.444566e-17  3.866740e-17
# std    1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00  1.001322e+00
# min   -3.913028e+00 -2.412655e+00 -1.233168e+00 -1.011062e+00 -1.332947e+00
# 25%   -6.037702e-01 -8.205934e-01 -8.072353e-01 -6.712517e-01 -7.848638e-01
# 50%   -1.357009e-01  3.052342e-01 -3.194761e-01 -5.579817e-01 -4.758382e-01
# 75%    4.969408e-01  8.871226e-01  6.580571e-01  1.594148e+00  1.459945e+00
# max    3.523362e+00  1.096747e+00  3.859730e+00  1.594148e+00  1.722325e+00
#
#            ...              9_9        9_10        9_11        9_12  \
# count      ...       379.000000  379.000000  379.000000  379.000000
# mean       ...         1.000000    0.475471   -0.439661    0.525110
# std        ...         0.850707    0.711694    1.286391    0.987850
# min        ...         0.000722   -0.963250   -5.565569   -2.655565
# 25%        ...         0.299570   -0.038492   -0.364909    0.006651
# 50%        ...         0.662624    0.321558   -0.207737    0.376491
# 75%        ...         2.131439    1.150679    0.013474    0.898023
# max        ...         2.966404    2.875829    0.839361    4.882979
#
#             10_10       10_11       10_12         11_11       11_12  \
# count  379.000000  379.000000  379.000000  3.790000e+02  379.000000
# mean     1.000000   -0.187913    0.346793  1.000000e+00   -0.392536
# std      1.345701    0.877412    0.988557  2.960282e+00    1.315404
# min      0.000002   -3.004628   -4.068103  3.610350e-07  -10.527741
# 25%      0.105839   -0.360579   -0.070585  1.076090e-01   -0.364196
# 50%      0.621205   -0.018674    0.239206  1.706008e-01   -0.161008
# 75%      1.286318    0.250718    0.781187  2.027940e-01    0.068942
# max      7.449589    5.075814    3.384938  1.453270e+01    1.409041
#
#               12_12
# count  3.790000e+02
# mean   1.000000e+00
# std    1.447182e+00
# min    5.866542e-07
# 25%    1.346489e-01
# 50%    5.460212e-01
# 75%    1.245982e+00
# max    1.118657e+01
#
# [8 rows x 104 columns]

# %%
X = df.values

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_scaled = scaler.transform(X)

# %%
X_ = np.append(X_scaled,np.ones(X_scaled.shape[0]).reshape(-1,1),axis=1)

# %%
X_.shape
# Out:
# (379, 105)

# %%
def cost(X_train,m,Y_train):
    cost_ = 0
    N = X_train.shape[0]
    for i in range(N):
        cost_ += (1/N)*((Y_train[i]-((X_train[i]*m).sum()))**2)
    return cost_

# %%
def step_gradient(X_train,Y_train,m,lr):
    
    slope_m = np.zeros(X_train.shape[1])
    N = X_train.shape[0]
    
    for i in range(N):
        slope_m += (2/N)*(Y_train[i]-(m*X_train[i]).sum())*(-X_train[i])
        
    m = m - (lr * slope_m)
    
    return m

# %%
def fit(X_train,Y_train,lr=0.001,epochs=100,verbose=False):
    m = np.zeros(X_train.shape[1])
    last_m = m
    least_m = m
    least_cost = 2147483648
    cost_array = []
    unit = epochs//100
    for i in range(epochs+1):
        last_m = m
        m = step_gradient(X_train,Y_train,m,lr)
        cost_ = cost(X_train,m,Y_train)
        #verbose is used to only show the learning process if required, else it is False by default
        if i>0:
            if cost_<least_cost:
                least_cost = cost_
                least_m = m
            if cost_>cost_array[-1]:
                m = least_m
                lr/=10
        if verbose and i%unit==0:
            print("epoch:",i,"cost:",cost_)
            cost_array.append(cost_)
    
    #To continue the learning loop incase the current epoch and learning parameters doesn't lead to saturation
    cont = input("Do you want to continue?:")
        
    while cont=="y":
        clear_output(wait=True)
        epochs = int(input("Please enter the number of epochs to continue for:"))
        unit = int(input("Please enter the unit point for epochs:"))
        lr_factor = float(input("Please enter the decay factor for the learning rate:"))
        lr*=lr_factor
        for i in range(epochs+1):
            last_m = m
            m = step_gradient(X_train,Y_train,m,lr)
            cost_ = cost(X_train,m,Y_train)
            if cost_<least_cost:
                least_cost = cost_
                least_m = m
            if i>0:
                if cost_>cost_array[-1]:
                    m = least_m
                    lr/=10
            if verbose and i%unit==0:
                print("epoch:",i,"cost:",cost_)
#   1.32159658e+00 -2.52279998e+00  2.11013282e+00 -1.45029310e-02
#  -2.63154063e-01 -1.58099604e+00 -1.01377001e+00  1.90226798e+00
#  -1.01172939e+00 -1.29243398e+00  4.05353504e-01  8.44981867e-02
#  -1.14674560e-01 -1.52308865e+00 -7.87562650e-01  8.99423991e-01
#   2.26094987e+01]

# %%
plt.plot(cost_array)
plt.grid()
plt.show()

# %%
y_pred = predict(X_,m)
y_pred.shape
# Out:
# (379,)

# %%
score(Y,y_pred)
# Out:
# 0.9315859172484514

# %%
X_test = np.loadtxt("Boston-Testing-Data.csv",delimiter=",")

# %%
df_test = pd.DataFrame(X_test)

# %%
features = df_test.columns

for feature1 in range(len(features)):
    for feature2 in range(feature1,len(features)):
        comp_feature = str(feature1) + "_" + str(feature2)
        df_test[comp_feature] = df_test[feature1]*df_test[feature2]
df_test.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000  127.000000
# mean    -0.058575   -0.007327   -0.107939   -0.086410   -0.085871   -0.096098
# std      0.769837    1.005445    0.945672    0.839435    1.003998    0.998196
# min     -0.417173   -0.487722   -1.557842   -0.272599   -1.431329   -3.058221
# 25%     -0.410832   -0.487722   -0.891036   -0.272599   -0.947582   -0.567918
# 50%     -0.398269   -0.487722   -0.375976   -0.272599   -0.299707   -0.127698
# 75%     -0.242900   -0.219475    1.015999   -0.272599    0.434551    0.283316
# max      3.966816    3.589637    2.117615    3.668398    2.732346    3.476688
#
#                 6           7           8           9     ...             9_9  \
# count  127.000000  127.000000  127.000000  127.000000     ...      127.000000
# mean    -0.114581    0.003845   -0.129240   -0.130670     ...        0.882064
# std      1.042254    0.920171    0.946051    0.933732     ...        0.858238
# min     -2.225199   -1.263551   -0.982843   -1.308051     ...        0.000269
# 25%     -1.240171   -0.762417   -0.637962   -0.785394     ...        0.181269
# 50%      0.111130   -0.202052   -0.523001   -0.601276     ...        0.571079
# 75%      0.898797    0.604198   -0.350561    0.072833     ...        1.263543
# max      1.117494    3.287300    1.661245    1.530926     ...        2.343736
#
#              9_10        9_11        9_12       10_10       10_11       10_12  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000  127.000000
# mean     0.389768   -0.402390    0.546343    1.005011   -0.137531    0.440862
# std      0.699492    1.191343    0.965995    1.277402    0.917870    0.812377
# min     -0.944951   -5.981626   -2.648924    0.000423   -3.542620   -0.848721
# 25%     -0.063342   -0.358187    0.007251    0.105174   -0.331425   -0.051847
# 50%      0.248849   -0.249002    0.337608    0.650565   -0.010328    0.201336
# 75%      1.234808   -0.011042    0.692886    1.384072    0.262398    0.681813
# max      2.160882    0.675218    5.432907    7.329902    5.103212    3.869947
#
#             11_11       11_12       12_12
# count  127.000000  127.000000  127.000000
# mean     0.912351   -0.252673    0.914621
# std      2.881870    1.004107    1.762049
# min      0.000205   -8.301719    0.000006
# 25%      0.130853   -0.343031    0.091965
# 50%      0.175848   -0.142530    0.311722
# 75%      0.194527    0.041927    1.015787
# max     15.266159    1.565192   12.593774
#
# [8 rows x 104 columns]

# %%
X_test = df_test.values

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled_ = np.append(X_test_scaled,np.ones(X_test_scaled.shape[0]).reshape(-1,1),axis=1)

# %%
y_pred_test = predict(X_test_scaled_,m)

# %%
np.savetxt('pred_dummy_features_feature_scaling_hetero.csv',y_pred_test)
