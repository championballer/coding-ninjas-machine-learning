# %%
import pandas as p
import numpy as np

import matplotlib.pyplot as plt

# %%
titanic = p.read_csv("test.csv")
survived = p.read_csv("survived.csv")
data = titanic.copy()
data.head()
data1 = survived.copy()

# %%
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data1.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
data["Survived"] = data1["Survived"]
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
data.drop("Name",axis=1,inplace = True)
data
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch              Ticket  \
# 0            892       3    male  34.5      0      0              330911
# 1            893       3  female  47.0      1      0              363272
# 2            894       2    male  62.0      0      0              240276
# 3            895       3    male  27.0      0      0              315154
# 4            896       3  female  22.0      1      1             3101298
# 5            897       3    male  14.0      0      0                7538
# 6            898       3  female  30.0      0      0              330972
# 7            899       2    male  26.0      1      1              248738
# 8            900       3  female  18.0      0      0                2657
# 9            901       3    male  21.0      2      0           A/4 48871
# 10           902       3    male   NaN      0      0              349220
# 11           903       1    male  46.0      0      0                 694
# ...

# %%
data.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Survived
# 0        Q         0
# 1        S         1
# 2        Q         0
# 3        S         0
# 4        S         1

# %%
data.dropna(axis=1).head()
# Out:
#    PassengerId  Pclass     Sex  SibSp  Parch   Ticket Embarked  Survived
# 0          892       3    male      0      0   330911        Q         0
# 1          893       3  female      1      0   363272        S         1
# 2          894       2    male      0      0   240276        Q         0
# 3          895       3    male      0      0   315154        S         0
# 4          896       3  female      1      1  3101298        S         1

# %%
data.drop("Cabin",axis=1).head()
m1 = data["Fare"].mean()
data["Fare"].fillna(m1)
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
# 5        9.2250
# 6        7.6292
# 7       29.0000
# 8        7.2292
# 9       24.1500
# 10       7.8958
# 11      26.0000
# 12      82.2667
# 13      26.0000
# 14      61.1750
# 15      27.7208
# 16      12.3500
# 17       7.2250
# 18       7.9250
# 19       7.2250
# 20      59.4000
# 21       3.1708
# 22      31.6833
# 23      61.3792
# 24     262.3750
# 25      14.5000
# 26      61.9792
# 27       7.2250
# 28      30.5000
# 29      21.6792
#          ...
# 388      7.7500
# 389     21.0750
# 390     93.5000
# 391     39.4000
# 392     20.2500
# 393     10.5000
# 394     22.0250
# 395     60.0000
# 396      7.2500
# 397     79.2000
# 398      7.7750
# 399      7.7333
# 400    164.8667
# 401     21.0000
# 402     59.4000
# 403     47.1000
# 404     27.7208
# 405     13.8625
# 406     10.5000
# 407    211.5000
# 408      7.7208
# 409     13.7750
# 410      7.7500
# 411     90.0000
# ...

# %%
p.options.mode.chained_assignment = None
data.head()
# m1 = data[data.Survived==0].Age.mean()
# df = data[data.Survived==0]
# df.Age.fillna(m1,inplace=True)
# df
# data[data.Survived==0]["Age"].fillna(m1,inplace=True)
nm = data.Age.mean()
nm0 = data[data.Survived==0].Age.mean()
nm1 = data[data.Survived==1].Age.mean()
print(nm)
print(nm0)
print(nm1)
# Out:
# 30.272590361445783
# 30.27273170731707
# 30.27236220472441

# %%
# data.Age.fillna(nm,inplace=True)
# #data.Age.fillna(nm,inplace=True)
# data

# %%
data.drop("Cabin",inplace=True,axis=1)
data
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch              Ticket  \
# 0            892       3    male  34.5      0      0              330911
# 1            893       3  female  47.0      1      0              363272
# 2            894       2    male  62.0      0      0              240276
# 3            895       3    male  27.0      0      0              315154
# 4            896       3  female  22.0      1      1             3101298
# 5            897       3    male  14.0      0      0                7538
# 6            898       3  female  30.0      0      0              330972
# 7            899       2    male  26.0      1      1              248738
# 8            900       3  female  18.0      0      0                2657
# 9            901       3    male  21.0      2      0           A/4 48871
# 10           902       3    male   NaN      0      0              349220
# 11           903       1    male  46.0      0      0                 694
# ...

# %%
data.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Embarked  \
# 0          892       3    male  34.5      0      0   330911   7.8292        Q
# 1          893       3  female  47.0      1      0   363272   7.0000        S
# 2          894       2    male  62.0      0      0   240276   9.6875        Q
# 3          895       3    male  27.0      0      0   315154   8.6625        S
# 4          896       3  female  22.0      1      1  3101298  12.2875        S
#
#    Survived
# 0         0
# 1         1
# 2         0
# 3         0
# 4         1

# %%
def con(a):
    if a =="male":
        return 1
    elif a=="female":
        return 0

data["Gender"]=data.Sex.apply(con)
data.head()
data.drop("Sex",inplace=True,axis=1)

# %%
data.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch   Ticket     Fare Embarked  \
# 0          892       3  34.5      0      0   330911   7.8292        Q
# 1          893       3  47.0      1      0   363272   7.0000        S
# 2          894       2  62.0      0      0   240276   9.6875        Q
# 3          895       3  27.0      0      0   315154   8.6625        S
# 4          896       3  22.0      1      1  3101298  12.2875        S
#
#    Survived  Gender
# 0         0       1
# 1         1       0
# 2         0       1
# 3         0       1
# 4         1       0

# %%
data[data.Survived==0].Age
data.Age.fillna(data[data.Survived==0].Age.mean(),inplace=True)
data
# Out:
#      PassengerId  Pclass        Age  SibSp  Parch              Ticket  \
# 0            892       3  34.500000      0      0              330911
# 1            893       3  47.000000      1      0              363272
# 2            894       2  62.000000      0      0              240276
# 3            895       3  27.000000      0      0              315154
# 4            896       3  22.000000      1      1             3101298
# 5            897       3  14.000000      0      0                7538
# 6            898       3  30.000000      0      0              330972
# 7            899       2  26.000000      1      1              248738
# 8            900       3  18.000000      0      0                2657
# 9            901       3  21.000000      2      0           A/4 48871
# 10           902       3  30.272732      0      0              349220
# 11           903       1  46.000000      0      0                 694
# ...
