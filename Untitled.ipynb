# %%
import numpy as np

# %%
m = np.ones(3,float)

# %%
m.dtype
# Out:
# dtype('float64')

# %%
m[0] = 2

# %%
m[1] = 3

# %%
m.reshape(-1,1)
# Out:
# array([[ 2.],
#        [ 3.],
#        [ 1.]])

# %%
x = np.ones((4,3),float)

# %%
x.shape
x.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-36e24477d86a> in <module>()
# ----> 1 x.shape
#       2 x.dtype
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
m.shape
# Out:
# (3,)

# %%
m = [[100.0,40,1],[200.0,80,1],[160.0,30,1],[400.0,80,1]]
x = [0.5,0.2,0.01]

# %%
m*x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a6c45b34451f> in <module>()
# ----> 1 m*x
#
# TypeError: can't multiply sequence by non-int of type 'list'
