# %%
import math as m

m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
import numpy as np

# %%
a = np.arange(10)
a.shape
# Out:
# (10,)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-74befb814698> in <module>()
# ----> 1 a.shape
#
# NameError: name 'a' is not defined

# %%
a = np.array([0,1,2,3])
b = np.array([2,3,4,5])
a.dot(b)
# Out:
# 26

# %%
c = np.matrix('1 2 4;3 4 5')
c.shape
# Out:
# (2, 3)

# %%
np.sum([[0,1],[0,5]],axis=1)
# Out:
# array([1, 5])
